# %% [markdown]
# # Group 66 Final Project

# %% [markdown]
# ---

# %% [markdown]
# ### *Research question/interests*

# %% [markdown]
# In this project, the aim is to investigate the changes air passenger traffic at Canadian airports over the years with closer focus on the effect of the global pandemic.
#
# - What is the busiest airport in Canada by observations on passenger numbers?
#
# - Is there linear relationship between number of flights and traveller choose?
#
# - Comparing between Pre-Covid 19 and Post-Covid 19 situation for Canadian air travel industry as whole? How large of an impact is that?

# %% [markdown]
# ---

# %% [markdown]
# ### Initial Dataset Analysis(IDA)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("../images/data/raw/projectdataset.csv")
df
# Out:
#        REF_DATE                  GEO           DGUID  \
# 0          2008               Canada  2016A000011124
# 1          2008               Canada  2016A000011124
# 2          2008               Canada  2016A000011124
# 3          2008               Canada  2016A000011124
# 4          2008               Canada  2016A000011124
# ...         ...                  ...             ...
# 46362      2020  Whale Cove, Nunavut             NaN
# 46363      2020  Whale Cove, Nunavut             NaN
# 46364      2020  Whale Cove, Nunavut             NaN
# 46365      2020  Whale Cove, Nunavut             NaN
# 46366      2020  Whale Cove, Nunavut             NaN
#
#                          Air passenger traffic     UOM  UOM_ID SCALAR_FACTOR  \
# 0      Total, passengers enplaned and deplaned  Number     223         units
# 1                          Passengers enplaned  Number     223         units
# 2                          Passengers deplaned  Number     223         units
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Milestone 5

# %% [markdown]
# ---

# %% [markdown]
# ### Task 1: Conduct an Exploratory Data Analysis (EDA) on your dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
print("Number of rows and columns respectively", df.shape)
print("Columns in the dataset", df.columns)
# Out:
# Number of rows and columns respectively (46367, 15)
# Columns in the dataset Index(['REF_DATE', 'GEO', 'DGUID', 'Air passenger traffic', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df.VALUE.describe()
# Out:
# count    1.689300e+04
# mean     1.103820e+06
# std      6.954191e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.834700e+04
# max      1.628641e+08
# Name: VALUE, dtype: float64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46367 entries, 0 to 46366
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REF_DATE               46367 non-null  int64
#  1   GEO                    46367 non-null  object
#  2   DGUID                  1456 non-null   object
#  3   Air passenger traffic  46367 non-null  object
#  4   UOM                    46367 non-null  object
#  5   UOM_ID                 46367 non-null  int64
#  6   SCALAR_FACTOR          46367 non-null  object
#  7   SCALAR_ID              46367 non-null  int64
#  8   VECTOR                 46367 non-null  object
#  9   COORDINATE             46367 non-null  float64
#  10  VALUE                  16893 non-null  float64
#  11  STATUS                 29474 non-null  object
#  12  SYMBOL                 0 non-null      float64
#  13  TERMINATED             0 non-null      float64
# ...

# %%
df["VALUE"].mean()
# Out:
# 1103819.8487539217

# %%
df.sort_values(by="VALUE", ascending=False).head()
# Out:
#        REF_DATE     GEO           DGUID  \
# 38623      2019  Canada  2016A000011124
# 38626      2019  Canada  2016A000011124
# 34978      2018  Canada  2016A000011124
# 34975      2018  Canada  2016A000011124
# 31386      2017  Canada  2016A000011124
#
#                          Air passenger traffic     UOM  UOM_ID SCALAR_FACTOR  \
# 38623  Total, passengers enplaned and deplaned  Number     223         units
# 38626                  Total, passenger sector  Number     223         units
# 34978                  Total, passenger sector  Number     223         units
# 34975  Total, passengers enplaned and deplaned  Number     223         units
# 31386                  Total, passenger sector  Number     223         units
#
#        SCALAR_ID     VECTOR  COORDINATE        VALUE STATUS  SYMBOL  \
# 38623          0  v65781694    100000.1  162864077.0    NaN     NaN
# 38626          0  v65781697    100000.4  162864077.0    NaN     NaN
# ...

# %% [markdown]
# ### Task 2-3: Analysis Pipeline And Method Chains

# %%
import project_functions1 as p1

# %%
data ='../projectdataset.csv'
dfu = p1.unprocessed(data)
dfu
# Out:
#        REF_DATE                  GEO           DGUID  \
# 0          2008               Canada  2016A000011124
# 1          2008               Canada  2016A000011124
# 2          2008               Canada  2016A000011124
# 3          2008               Canada  2016A000011124
# 4          2008               Canada  2016A000011124
# ...         ...                  ...             ...
# 46362      2020  Whale Cove, Nunavut             NaN
# 46363      2020  Whale Cove, Nunavut             NaN
# 46364      2020  Whale Cove, Nunavut             NaN
# 46365      2020  Whale Cove, Nunavut             NaN
# 46366      2020  Whale Cove, Nunavut             NaN
#
#                          Air passenger traffic     UOM  UOM_ID SCALAR_FACTOR  \
# 0      Total, passengers enplaned and deplaned  Number     223         units
# 1                          Passengers enplaned  Number     223         units
# 2                          Passengers deplaned  Number     223         units
# ...

# %%
dfp = p1.load_and_process(data)
dfp
# Out:
#      REF_DATE                                                GEO  \
# 0        2008               Deer Lake, Newfoundland and Labrador
# 1        2008    Gander International, Newfoundland and Labrador
# 2        2008               Goose Bay, Newfoundland and Labrador
# 3        2008  St John's International, Newfoundland and Labr...
# 4        2008                  Wabush, Newfoundland and Labrador
# ..        ...                                                ...
# 644      2020                   Hay River, Northwest Territories
# 645      2020           Inuvik/Mike Zubko, Northwest Territories
# 646      2020                 Yellowknife, Northwest Territories
# 647      2020                              Rankin Inlet, Nunavut
# 648      2020                              Resolute Bay, Nunavut
#
#        Air passenger traffic      VALUE
# 0    Total, passenger sector   272050.0
# 1    Total, passenger sector    93646.0
# 2    Total, passenger sector    91466.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Task 4: Conduct analysis to help answer research questions

# %%
print("Number of rows and columns respectively:", dfp.shape)
print("Columns in the dataset:", dfp.columns)
# Out:
# Number of rows and columns respectively: (649, 4)
# Columns in the dataset: Index(['REF_DATE', 'GEO', 'Air passenger traffic', 'VALUE'], dtype='object')

# %% [markdown]
# ##### **Graph 1**

# %%
df4= dfp.groupby('REF_DATE').sum().reset_index()
df4
# Out:
#     REF_DATE        VALUE
# 0       2008  104459474.0
# 1       2009   98350043.0
# 2       2010  102551922.0
# 3       2011  106423315.0
# 4       2012  111198607.0
# 5       2013  115697629.0
# 6       2014  120941169.0
# 7       2015  125175601.0
# 8       2016  132277819.0
# 9       2017  141999774.0
# 10      2018  151181519.0
# 11      2019  153732436.0
# 12      2020   42592976.0

# %%
a4_dims = (25, 10)
ax= sns.lineplot(data=df4, x="REF_DATE", y="VALUE")
ax.set_xlabel("Year")
ax.set_ylabel("Total Passenger Count")
# Out:
# Text(0, 0.5, 'Total Passenger Count')

# %%
dfp.loc[dfp['VALUE'].idxmax()]
# Out:
# REF_DATE                                                            2019
# GEO                      Toronto/Lester B Pearson International, Ontario
# Air passenger traffic                            Total, passenger sector
# VALUE                                                         49187804.0
# Name: 575, dtype: object

# %%
dfp.groupby([pd.Grouper(level=0), "REF_DATE"]).sum()
# Out:
#                   VALUE
#     REF_DATE
# 0   2008       272050.0
# 1   2008        93646.0
# 2   2008        91466.0
# 3   2008      1179630.0
# 4   2008        79974.0
# ...                 ...
# 644 2020        18420.0
# 645 2020        32327.0
# 646 2020       216529.0
# 647 2020        81871.0
# 648 2020         4371.0
#
# [649 rows x 1 columns]

# %% [markdown]
# ##### **Graph2**

# %%
df5= dfp.sort_values(by='VALUE', ascending=False).head(10)
df5
# Out:
#      REF_DATE                                              GEO  \
# 575      2019  Toronto/Lester B Pearson International, Ontario
# 522      2018  Toronto/Lester B Pearson International, Ontario
# 471      2017  Toronto/Lester B Pearson International, Ontario
# 424      2016  Toronto/Lester B Pearson International, Ontario
# 375      2015  Toronto/Lester B Pearson International, Ontario
# 327      2014  Toronto/Lester B Pearson International, Ontario
# 282      2013  Toronto/Lester B Pearson International, Ontario
# 230      2012  Toronto/Lester B Pearson International, Ontario
# 173      2011  Toronto/Lester B Pearson International, Ontario
# 117      2010  Toronto/Lester B Pearson International, Ontario
#
#        Air passenger traffic       VALUE
# 575  Total, passenger sector  49187804.0
# 522  Total, passenger sector  48494047.0
# 471  Total, passenger sector  45884420.0
# 424  Total, passenger sector  42889733.0
# 375  Total, passenger sector  39640129.0
# ...

# %%
tips = sns.load_dataset("tips")
ax = sns.barplot(y="VALUE", x="REF_DATE", data=df5)
ax.set_title("Top 10 airport with most passenger in 10 year ")
# Out:
# Text(0.5, 1.0, 'Top 10 airport with most passenger in 10 year ')

# %% [markdown]
# ##### **Graph 1 and 2 Analysis**
# - With limited total passenger count on graph 1, it is still observable that a linear increase in Canadian airport passenger count from 2009-2019, with the highest passenger count in 2019 and a significant decrease in 2020 due to the impact from the pandemic, therefore 2020 is out of the graph 2.
# - For the 2020 result, it is only close to 1/3 of the 2019 result and 1/2 the 2008 result.
# - Based on the table, Toronto/Lester B Pearson International Airport has the most total passenger count in various years. The most passenger count observed is 49187804.0 person count in 2019.
# - For a decade, it is undeniable that Toronto has the busiest passenger flow in Canada compared with the other Canadian international airports such as the Vancouver airport or Montreal airport as it takes lead for 10 year period based on graph2.

# %% [markdown]
# ---

# %% [markdown]
# ##### **Graph 3**

# %%
dfc= dfp.loc[dfp['GEO'].isin(['Vancouver International, British Columbia','Québec/Jean Lesage International, Quebec','Edmonton International, Alberta','Calgary International, Alberta','Halifax/Robert L Stanfield International, Nova Scotia','Winnipeg/James Armstrong Richardson International, Manitoba','Saskatoon/John G Diefenbaker International, Saskatchewan','Montréal/Pierre Elliott Trudeau International, Quebec','Toronto/Lester B Pearson International, Ontario','Ottawa/Macdonald-Cartier International, Ontario'])]
ax = sns.lmplot(data=dfc, x="REF_DATE",y="VALUE",hue="GEO")
ax.fig.set_size_inches(15,10)
ax.fig.suptitle("Yearly Passenger Count For Famous 10 Candian Cities for tourists")
plt.show()

# %% [markdown]
# ##### **Graph 4**

# %%
ax=sns.jointplot(data=dfc, x="REF_DATE",y="VALUE",hue="GEO")
ax.fig.set_size_inches(10,10)
ax.fig.suptitle("Yearly Passenger Count For Famous 10 Candian Cities for tourists")
plt.show()

# %% [markdown]
# ##### **Graph 3 and Graph 4 Analysis**

# %% [markdown]
# Based on the plot of the yearly passenger count for the famous cities over Canada, trendlines on graph 4 show that almost all the cities are steadily on a net incline, with Toronto airport having a much steeper slope compared to other airports; even though the pandemic caused the declining in 2020. We can then assume that before the pandemic, the general public is becoming more dependent on traveling through planes, according to similar result from graph 4. However, the dataset may seem monotonous it is only provided with passenger count in a given year and its locations but not a survey based on true reflection on how travelers feel about the convenience of air travel. Over the decades, Canadian cities are gradually becoming hotspots for domestic and international travelers, traveling by plane will likely become more popular.

# %% [markdown]
# ##### **Conclusion: Formal Analysis to research questions**

# %% [markdown]
# - From graphs 2, 3 and 4, it is not hard to observe that Toronto has the busiest airport in Canada over the decade. Serving more than 50 million passengers in 2019. This ambitious record, in other words, is equivalent to the sum of many other "big" airports in Canada.
# - It is noticeable a linear relationship between the number of flights with the famous cities. As the two well-known cities, Vancouver and Toronto are responsible to take connecting large amount flights to take international travelers to their final destinations as they control the west coast and east coast air travel industry. That means it is ambiguous to answer this question as there could be travelers not considering Vancouver or Toronto as the places they intend to visit but only for a connection flight, based on the limited result we have on the dataset. But one thing we can assume is that such cities that can take connection flights have a positive impact on attracting travelers to visit those cities.
# - The pandemic starts affecting in early 2020. Based on graph 1, we are seeing total passenger count in 2020 is only close to half of the total passenger count in 2008.

# %% [markdown]
# #### References:

# %% [markdown]
# https://open.canada.ca/data/en/dataset/86e2e0c7-150b-4a2b-b90c-ebc62f26f8a2
